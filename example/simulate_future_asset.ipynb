# %%
if "xxx" in globals():
    pass
else:
    import os,glob
    currentdir = os.getcwd()
xxx = True
os.chdir(currentdir)
os.chdir("../")
print("maindir=",os.getcwd())

from assetsim_main import get_exe_dir,read_json_as_dict,save_dict_as_json,AssetSimulator
# Out:
# maindir= /home/tajimamainpc/repos/asset_simulator

# %% [markdown]
# # 資産形成計画の準備
# - asset_plan.csvを編集する

# %% [markdown]
# # 資産推移計算

# %%
maindir = get_exe_dir()
cond = {
    "output_dir": f"{currentdir}/result",
    "asset_plan_in": f"{currentdir}/asset_plan.csv",
    "sock_database_path": f"{maindir}/database",
    "fig_mode": "plotly",
    "is_show": True,# Trueでノートブックにも表示
    "single_life_mode": True,
    "initial_year": 2025,
    "initial_cash": 1000000,
    "initial_invest_asset": 0,
    "inflation_rate": 1.02,
    "multi_life_mode": True,
    "number_of_life": 10000,
    "check_years": [
        2026,
        2030,
        2040,
        2050,
        2060,
        2070,
        2080,
        2090
    ],
    "asset_threshold": 20000000,
    "achieve_percents": [
        70,
        80,
        90,
        95,
        99
    ]
}
js_in = f"{maindir}/example/condition.json"
save_dict_as_json(cond, js_in)

# %%
maindir = get_exe_dir()
js_in = f"{maindir}/example/condition.json"
cond = read_json_as_dict(js_in)
os.makedirs(cond["output_dir"], exist_ok=True)
AS = AssetSimulator(js_in)
AS.check_plan()
AS.cal_asset()
# Out:
# 100%|██████████| 10000/10000 [00:05<00:00, 1873.10it/s]
